# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt
import numpy as np
from scipy import stats

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# Define the file path
file_path = "/content/drive/MyDrive/aaaaaaaaaaa/loan_data_set.csv"  # Update with your file path

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

# Display the first few rows of the DataFrame
print(df.head())
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df.isnull().sum()*100/len(df)
# Out:
# Loan_ID              0.000000
# Gender               2.117264
# Married              0.488599
# Dependents           2.442997
# Education            0.000000
# Self_Employed        5.211726
# ApplicantIncome      0.000000
# CoapplicantIncome    0.000000
# LoanAmount           3.583062
# Loan_Amount_Term     2.280130
# Credit_History       8.143322
# Property_Area        0.000000
# Loan_Status          0.000000
# dtype: float64

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
for i in df.columns[1:6]:
  print(f"The mode of {i} is {df[i].mode()[0]}\nCategories_Counts are\n{df[i].value_counts()}")
  print("----------------------------------------------------------------------")
# Out:
# The mode of Gender is Male
# Categories_Counts are
# Male      489
# Female    112
# Name: Gender, dtype: int64
# ----------------------------------------------------------------------
# The mode of Married is Yes
# Categories_Counts are
# Yes    398
# No     213
# Name: Married, dtype: int64
# ----------------------------------------------------------------------
# The mode of Dependents is 0
# Categories_Counts are
# 0     345
# 1     102
# 2     101
# 3+     51
# Name: Dependents, dtype: int64
# ----------------------------------------------------------------------
# The mode of Education is Graduate
# Categories_Counts are
# Graduate        480
# Not Graduate    134
# Name: Education, dtype: int64
# ----------------------------------------------------------------------
# The mode of Self_Employed is No
# Categories_Counts are
# No     500
# Yes     82
# Name: Self_Employed, dtype: int64
# ----------------------------------------------------------------------

# %%
for i in df.columns[10:13]:
  print(f"The mode of {i} is {df[i].mode()[0]}\nCategories_Counts are\n{df[i].value_counts()}")
  print("----------------------------------------------------------------------")
# Out:
# The mode of Credit_History is 1.0
# Categories_Counts are
# 1.0    475
# 0.0     89
# Name: Credit_History, dtype: int64
# ----------------------------------------------------------------------
# The mode of Property_Area is Semiurban
# Categories_Counts are
# Semiurban    233
# Urban        202
# Rural        179
# Name: Property_Area, dtype: int64
# ----------------------------------------------------------------------
# The mode of Loan_Status is Y
# Categories_Counts are
# Y    422
# N    192
# Name: Loan_Status, dtype: int64
# ----------------------------------------------------------------------

# %%
df.shape[1]
# Out:
# 13

# %%
#filling nan value
for i in df.columns:
  df[i].fillna(df[i].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
for i in df.columns[1:6]:
  df[i] = le.fit_transform(df[i])

# %%
for i in df.columns[9:13]:
  df[i] = le.fit_transform(df[i])

# %%
df.head(5)
# Out:
#     Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0  LP001002       1        0           0          0              0
# 1  LP001003       1        1           1          0              0
# 2  LP001005       1        1           0          0              1
# 3  LP001006       1        1           0          1              0
# 4  LP001008       1        0           0          0              0
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0       120.0                 8
# 1             4583             1508.0       128.0                 8
# 2             3000                0.0        66.0                 8
# 3             2583             2358.0       120.0                 8
# 4             6000                0.0       141.0                 8
#
#    Credit_History  Property_Area  Loan_Status
# 0               1              2            1
# 1               1              0            0
# ...

# %%
for i in df.columns[1:6]:
  print(f"{i}------>{df[i].unique()}")
  print("-------------------------------------")
# Out:
# Gender------>[1 0]
# -------------------------------------
# Married------>[0 1]
# -------------------------------------
# Dependents------>[0 1 2 3]
# -------------------------------------
# Education------>[0 1]
# -------------------------------------
# Self_Employed------>[0 1]
# -------------------------------------

# %%
df.drop("Loan_ID",axis=1,inplace=True)

# %%
df
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        0           0          0              0             5849
# 1         1        1           1          0              0             4583
# 2         1        1           0          0              1             3000
# 3         1        1           0          1              0             2583
# 4         1        0           0          0              0             6000
# ..      ...      ...         ...        ...            ...              ...
# 609       0        0           0          0              0             2900
# 610       1        1           3          0              0             4106
# 611       1        1           1          0              0             8072
# 612       1        1           2          0              0             7583
# 613       0        0           0          0              1             4583
#
# ...

# %%
X = df.drop("Loan_Status",axis=1)
y = df['Loan_Status']

# %%
from sklearn.preprocessing import StandardScaler
st = StandardScaler()

# %%
EncodedX = st.fit_transform(X.astype(int))

# %%
X = pd.DataFrame(EncodedX, columns = X.columns)
X
# Out:
#        Gender   Married  Dependents  Education  Self_Employed  \
# 0    0.472343 -1.372089   -0.737806  -0.528362      -0.392601
# 1    0.472343  0.728816    0.253470  -0.528362      -0.392601
# 2    0.472343  0.728816   -0.737806  -0.528362       2.547117
# 3    0.472343  0.728816   -0.737806   1.892641      -0.392601
# 4    0.472343 -1.372089   -0.737806  -0.528362      -0.392601
# ..        ...       ...         ...        ...            ...
# 609 -2.117107 -1.372089   -0.737806  -0.528362      -0.392601
# 610  0.472343  0.728816    2.236021  -0.528362      -0.392601
# 611  0.472343  0.728816    0.253470  -0.528362      -0.392601
# 612  0.472343  0.728816    1.244745  -0.528362      -0.392601
# 613 -2.117107 -1.372089   -0.737806  -0.528362       2.547117
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0           0.072991          -0.554487   -0.302759          0.299776
# 1          -0.134412          -0.038731   -0.207648          0.299776
# ...

# %%
X.describe()
# Out:
#              Gender       Married    Dependents     Education  Self_Employed  \
# count  6.140000e+02  6.140000e+02  6.140000e+02  6.140000e+02   6.140000e+02
# mean  -8.100650e-17  6.654105e-17  2.893089e-18  1.735854e-17  -3.761016e-17
# std    1.000815e+00  1.000815e+00  1.000815e+00  1.000815e+00   1.000815e+00
# min   -2.117107e+00 -1.372089e+00 -7.378063e-01 -5.283622e-01  -3.926007e-01
# 25%    4.723426e-01 -1.372089e+00 -7.378063e-01 -5.283622e-01  -3.926007e-01
# 50%    4.723426e-01  7.288155e-01 -7.378063e-01 -5.283622e-01  -3.926007e-01
# 75%    4.723426e-01  7.288155e-01  2.534696e-01 -5.283622e-01  -3.926007e-01
# max    4.723426e-01  7.288155e-01  2.236021e+00  1.892641e+00   2.547117e+00
#
#        ApplicantIncome  CoapplicantIncome    LoanAmount  Loan_Amount_Term  \
# count     6.140000e+02       6.140000e+02  6.140000e+02      6.140000e+02
# mean     -4.339634e-18       3.182398e-17 -5.786179e-17      1.171701e-16
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score

# %%
model_df = {}
def model_eval(model,X,y):
  X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=1)
  model.fit(X_train,y_train)
  y_preds = model.predict(X_test)
  print("Accuracy Score=",accuracy_score(y_test,y_preds))
  score = cross_val_score(model,X,y,cv=5)
  model_df[model]=accuracy_score
  print(f"{model} individual fold cross val score is {score}")
  print(f"{model} Avg cross val score is {np.mean(score)}")
  model_df[model] = round(np.mean(score)*100,2)

# %%
from sklearn.linear_model import LogisticRegression,LinearRegression,RidgeClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier,AdaBoostClassifier,VotingClassifier
from xgboost  import XGBClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report,accuracy_score,f1_score,confusion_matrix
from sklearn.model_selection import RandomizedSearchCV

# %%
lr = LogisticRegression()
rc = RidgeClassifier()
sv = SVC()
dtc = DecisionTreeClassifier()
rfc = RandomForestClassifier()
gbc = GradientBoostingClassifier()
abc = AdaBoostClassifier()
#vc = VotingClassifier()
xgbc = XGBClassifier()
lda = LinearDiscriminantAnalysis()
knn  = KNeighborsClassifier()
# gnb = GassianNB()

# %%
list = [lr,rc,sv,dtc,rfc,gbc,abc,xgbc,lda,knn]
for i in list:
  model_eval(i,X,y)
# Out:
# Accuracy Score= 0.7967479674796748
# LogisticRegression() individual fold cross val score is [0.81300813 0.77235772 0.7804878  0.84552846 0.81147541]
# LogisticRegression() Avg cross val score is 0.8045715047314408
# Accuracy Score= 0.8048780487804879
# RidgeClassifier() individual fold cross val score is [0.81300813 0.7804878  0.7804878  0.84552846 0.81967213]
# RidgeClassifier() Avg cross val score is 0.8078368652538984
# Accuracy Score= 0.8048780487804879
# SVC() individual fold cross val score is [0.81300813 0.78861789 0.7804878  0.82926829 0.81147541]
# SVC() Avg cross val score is 0.8045715047314406
# Accuracy Score= 0.6991869918699187
# DecisionTreeClassifier() individual fold cross val score is [0.76422764 0.66666667 0.7398374  0.75609756 0.73770492]
# DecisionTreeClassifier() Avg cross val score is 0.732906837265094
# Accuracy Score= 0.7723577235772358
# RandomForestClassifier() individual fold cross val score is [0.78861789 0.74796748 0.77235772 0.81300813 0.7704918 ]
# ...

# %%
model_df
# Out:
# {LogisticRegression(): 80.46,
#  RidgeClassifier(): 80.78,
#  SVC(): 80.46,
#  DecisionTreeClassifier(): 73.29,
#  RandomForestClassifier(): 77.85,
#  GradientBoostingClassifier(): 78.01,
#  AdaBoostClassifier(): 78.82,
#  XGBClassifier(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=None, device=None, early_stopping_rounds=None,
#                enable_categorical=False, eval_metric=None, feature_types=None,
#                gamma=None, grow_policy=None, importance_type=None,
#                interaction_constraints=None, learning_rate=None, max_bin=None,
#                max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=None, max_leaves=None,
#                min_child_weight=None, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=None, n_jobs=None,
# ...

# %%
params = {'C':np.logspace(-4,4,20),'solver':['liblinear','lbfgs','sag','saga']}
rslr = RandomizedSearchCV(lr,param_distributions=params, n_iter = 20, cv = 5, verbose = True, random_state=5)
rslr.fit(X,y)
print(rslr.best_score_)
print(rslr.best_params_)
print(rslr.best_estimator_)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# 0.809462881514061
# {'solver': 'lbfgs', 'C': 0.03359818286283781}
# LogisticRegression(C=0.03359818286283781)

# %%
params = {'C':np.arange(0,15),'kernel':['rbf','poly','sigmoid']}
rssv = RandomizedSearchCV(sv,param_distributions=params, n_iter=5,verbose=True)
rssv.fit(X,y)
print(rssv.best_params_)
print(rssv.best_score_)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# {'kernel': 'rbf', 'C': 4}
# 0.7850193256030921

# %%
params = {'C':np.arange(0,15),'kernel':['rbf','linear','poly','sigmoid']}
rssv = RandomizedSearchCV(sv,param_distributions=params, n_iter=5,cv=5,verbose=True)
rssv.fit(X,y)
print(rssv.best_params_)
print(rssv.best_score_)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# {'kernel': 'linear', 'C': 8}
# 0.809462881514061

# %%
params = {'n_estimators':np.arange(100,1000,100),
          'max_features':['auto','sqrt'],
          'max_depth':np.arange(0,50,10),
          'min_samples_split':np.arange(1,20,10),
          'min_samples_leaf':np.arange(1,10,2)}
rsrfc = RandomizedSearchCV(rfc,param_distributions=params,n_iter=5,cv=5,verbose=True)
rsrfc.fit(X,y)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# ...

# %%
print(rsrfc.best_params_)
print(rsrfc.best_score_)
# Out:
# {'n_estimators': 200, 'min_samples_split': 11, 'min_samples_leaf': 7, 'max_features': 'auto', 'max_depth': 30}
# 0.809462881514061

# %%
rf = RandomForestClassifier(n_estimators=270,min_samples_split=5,min_samples_leaf=5,max_features='sqrt',max_depth=5)

# %%
import pandas as pd
df = pd.DataFrame({'Gender':1,
                   'Married':1,
                   'Dependents':2,
                   'Education':0,
                   'Self_Employed':0,
                   'ApplicantIncome':2889,
                   'CoapplicantIncome':0.0,
                   'LoanAmount':45,
                   'Loan_Amount_Term':180,
                   'Credit_History':0,
                   'Property_Area':1},index=[0])

# %%
df
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       1        1           2          0              0             2889
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0          45               180               0
#
#    Property_Area
# 0              1

# %%
result = knn.predict(df)
if result==1:
  print("Loan Approved")
else:
  print('Loan Not Approved')
# Out:
# Loan Approved
